# %% [markdown]
# # Tree-based Predicting Models

# %% [markdown]
# **Load necessary packages**

# %% [markdown]
# General packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split, cross_val_score
import sklearn.model_selection as skm
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots

# %% [markdown]
# Tree-based methods packages

# %%
from sklearn.tree import (DecisionTreeClassifier as DTC,
                          DecisionTreeRegressor as DTR,
                          plot_tree,
                          export_text)
from sklearn.metrics import (accuracy_score,
                             log_loss)
from sklearn.ensemble import \
     (RandomForestClassifier as RFC,
      GradientBoostingClassifier as GBC)

# %% [markdown]
# *packages used to tune the hyperparameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## 1. Load data

# %%
raw = pd.read_csv("training.csv")
raw
# Out:
#        query_id  url_id  query_length  is_homepage  sig1  sig2  sig3  sig4  \
# 0          4631   28624             2            1  0.09  0.15  1288   352
# 1          4631   28625             2            1  0.20  0.35  4662   337
# 2          4631   28626             2            1  0.36  0.49  1121   385
# 3          4631   28627             2            1  0.21  0.45  2925   478
# 4          4631   28628             2            1  0.25  0.42  1328   429
# ...         ...     ...           ...          ...   ...   ...   ...   ...
# 80041     17038  102812             1            0  0.13  0.29    10     7
# 80042     17038  102813             1            0  0.12  0.20   121     0
# 80043     17038  102814             1            0  0.04  0.37   179    15
# 80044     17038  102815             1            0  0.22  0.50   643   223
# 80045     17038  102816             1            0  0.38  0.37   937   145
#
#        sig5  sig6  sig7  sig8  relevance            id
# 0       376    13  0.46  0.35          0   4631.286240
# 1       666    28  0.43  0.27          1   4631.286250
# 2       270    15  0.34  0.20          1   4631.286260
# 3       640    14  0.44  0.33          1   4631.286270
# 4       412    27  0.40  0.57          1   4631.286280
# ...     ...   ...   ...   ...        ...           ...
# 80041    10     0  0.25  0.79          0  17038.102812
# 80042    46     1  0.30  0.50          0  17038.102813
# 80043    92     0  0.32  0.42          0  17038.102814
# 80044   114    10  0.32  0.86          1  17038.102815
# 80045   130    15  0.47  0.89          1  17038.102816
#
# [80046 rows x 14 columns]

# %% [markdown]
# ## 2. Exploratory data analysis

# %% [markdown]
# **Check if there are missing data.**

# %%
missing_values = raw.isnull().sum()
missing_values
# raw = raw.dropna()
# Out:
# query_id        0
# url_id          0
# query_length    0
# is_homepage     0
# sig1            0
# sig2            0
# sig3            0
# sig4            0
# sig5            0
# sig6            0
# sig7            0
# sig8            0
# relevance       0
# id              0
# dtype: int64

# %% [markdown]
# No missing data.

# %% [markdown]
# **Check duplicates**

# %%
duplicates = raw.duplicated()
num_duplicates = duplicates.sum()
num_duplicates
# raw = raw.drop_duplicates()
# Out:
# 0

# %% [markdown]
# No duplicates

# %% [markdown]
# ## 3. Declare predictors and target variable.

# %%
X = raw.drop(['relevance', 'query_id', 'url_id', 'id'], axis=1)
y = raw['relevance']

# %% [markdown]
# ## 4. Scale the predictors

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns = X.columns)
X_scaled.describe()
# Out:
#        query_length   is_homepage          sig1          sig2          sig3  \
# count  8.004600e+04  8.004600e+04  8.004600e+04  8.004600e+04  8.004600e+04
# mean   5.378880e-16 -3.245814e-15  1.634555e-15  7.155055e-17 -1.835163e-16
# std    1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00
# min   -1.041878e+00 -6.065367e-01 -1.243548e+00 -2.010775e+00 -2.064047e-01
# 25%   -3.848838e-01 -6.065367e-01 -7.006331e-01 -7.936921e-01 -2.030900e-01
# 50%   -3.848838e-01 -6.065367e-01 -2.255822e-01 -4.026011e-02 -1.886840e-01
# 75%    2.721100e-01  1.648705e+00  3.851975e-01  7.711282e-01 -9.856135e-02
# max    1.012702e+01  1.648705e+00  5.542893e+00  2.973468e+00  2.842023e+01
#
#                sig4          sig5          sig6          sig7          sig8
# count  8.004600e+04  8.004600e+04  8.004600e+04  8.004600e+04  8.004600e+04
# mean   6.762345e-16  1.491757e-16 -4.457561e-15 -2.817070e-16 -6.917763e-16
# std    1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00
# min   -1.540609e-01 -2.916050e-01 -1.565392e-01 -2.304098e+00 -2.039932e+00
# 25%   -1.490800e-01 -2.863082e-01 -1.565392e-01 -7.173708e-01 -7.861737e-01
# 50%   -1.084019e-01 -2.577053e-01 -1.565392e-01 -6.825495e-02 -5.121198e-02
# 75%   -3.140430e-02 -1.136316e-01 -1.343338e-01  7.251088e-01  7.269828e-01
# max    1.370178e+02  2.460031e+01  4.031295e+01  4.042812e+00  2.023974e+00

# %% [markdown]
# ## 5. Visualize Attributes and Relationships by combination of pairplots and heatmaps

# %% [markdown]
# **Pairplots**

# %%
sns.pairplot(X_scaled)
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# **Heat map for correlation**

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(X_scaled.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Model Fitting

# %% [markdown]
# ## I. Decision Tree

# %% [markdown]
# **Split the data into training and testing sets (80% training set and 20% test set)**

# %%
#X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=666)

# %% [markdown]
# ### 1. Unpruned Decision Tree

# %% [markdown]
# **Initialize and fit the Decision Tree Classifier**

# %%
#dtc = DTC(random_state=666)
#dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=666)

# %% [markdown]
# **Predict on the test set**

# %%
#y_pred = dtc.predict(X_test)

# %% [markdown]
# **Evaluate the model**

# %%
#print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[5573 3391]
#  [3469 3577]]

# %%
#print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62      8964
#            1       0.51      0.51      0.51      7046
#
#     accuracy                           0.57     16010
#    macro avg       0.56      0.56      0.56     16010
# weighted avg       0.57      0.57      0.57     16010

# %%
#print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.5715178013741412

# %% [markdown]
# **Feature importance plot**

# %%
#importances = rf_model.feature_importances_
#indices = np.argsort(importances)[::-1]

#plt.figure(figsize=(12, 6))
#plt.title("Feature Importances")
#plt.bar(range(X_train.shape[1]), importances[indices], align="center")
#plt.xticks(range(X_train.shape[1]), X_scaled.columns[indices], rotation=90)
#plt.show()

# %% [markdown]
# ### 2. Pruned Decision Tree

# %% [markdown]
# Then, we use cross-validation to prune the tree on the training set

# %% [markdown]
# **Cross-validation to find the optimal ccp_alpha**

# %% [markdown]
# Obtain the path with ccp_alphas

# %%
#clf = DTC(random_state=666)
#path = clf.cost_complexity_pruning_path(X_train, y_train)
#ccp_alphas = path.ccp_alphas

# %% [markdown]
# Perform 5-fold cross-validation for each ccp_alpha to find the best one

# %%
#cv_scores = []
#for ccp_alpha in ccp_alphas:
#    clf = DTC(random_state=666, ccp_alpha=ccp_alpha)
#    scores = cross_val_score(clf, X_train, y_train, cv=5)
#    cv_scores.append(scores.mean())

# %% [markdown]
# Find the best ccp_alpha with the highest cross-validation score

# %%
#optimal_ccp_alpha = ccp_alphas[np.argmax(cv_scores)]
#optimal_ccp_alpha
# Out:
# 0.00014593059507960718

# %% [markdown]
# Plot cross-validation scores against ccp_alpha to visualize

# %%
#plt.figure(figsize=(8, 6))
#plt.plot(ccp_alphas, cv_scores, marker='o', drawstyle="steps-post")
#plt.xlabel('ccp_alpha')
#plt.ylabel('Cross-Validation Accuracy')
#plt.title('Cross-Validation Accuracy vs ccp_alpha')
#plt.show()

# %% [markdown]
# **Prune the tree with the optimal ccp_alpha**

# %%
#pruned_clf = DTC(random_state=666, ccp_alpha=optimal_ccp_alpha)
#pruned_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.00014593059507960718, random_state=666)

# %% [markdown]
# **Pridict the pruned tree on the test set**

# %%
#y_pred_pruned = pruned_clf.predict(X_test)

# %% [markdown]
# **Evaluate the pruned tree on the test set**

# %%
#print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_pruned))
# Out:
# Confusion Matrix:
#  [[7187 1777]
#  [3805 3241]]

# %%
#print("Classification Report:\n", classification_report(y_test, y_pred_pruned))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.80      0.72      8964
#            1       0.65      0.46      0.54      7046
#
#     accuracy                           0.65     16010
#    macro avg       0.65      0.63      0.63     16010
# weighted avg       0.65      0.65      0.64     16010

# %%
#print("Accuracy Score:", accuracy_score(y_test, y_pred_pruned))
# Out:
# Accuracy Score: 0.6513429106808245

# %% [markdown]
# **Feature importance plot**

# %%
#importances = pruned_clf.feature_importances_
#indices = np.argsort(importances)[::-1]

#plt.figure(figsize=(12, 6))
#plt.title("Feature Importances")
#plt.bar(range(X_train.shape[1]), importances[indices], align="center")
#plt.xticks(range(X_train.shape[1]), X_scaled.columns[indices], rotation=90)
#plt.xlabel('Feature')
#plt.ylabel('Importance')
#plt.show()

# %% [markdown]
# **Predict the classification for the test data**

# %%
#test_data = pd.read_csv("test.csv")
#X_true_test = test_data.drop(['query_id', 'url_id', 'id'], axis=1, errors='ignore')
#X_true_test_scaled = scaler.transform(X_true_test)
#predictions = pruned_clf.predict(X_true_test_scaled)
#results = pd.DataFrame({
#    'prediction': predictions,
#    'id': test_data['id']
#})

#results.to_csv("pruned_tree_predictions.csv", index=False)

# %% [markdown]
# ## II. Random Forest

# %% [markdown]
# **Split the data into training and test sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=666)

# %% [markdown]
# **Define the parameter grid for Grid Search**

# %%
param_grid = {
    'max_depth': [3, 5, 7, 10, 15, 20, None],  # Different depths of the decision trees
    'min_samples_split': [2, 5, 10, 15, 20]    # Minimum number of samples required to split an internal node
}

# %% [markdown]
# **Initialize the RandomForestClassifier**

# %%
rfc = RFC(random_state=666)

# %% [markdown]
# **Perform Grid Search with Cross-Validation to find the best parameters**

# %%
grid_search = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

# %% [markdown]
# **Print the best parameters and the best score from Grid Search**

# %%
print(f"Best parameters: {grid_search.best_params_}")

# %%
print(f"Best score: {grid_search.best_score_:.4f}")

# %% [markdown]
# **Train the RandomForestClassifier with the best parameters**

# %%
best_rfc = grid_search.best_estimator_
y_pred = best_rfc.predict(X_test)
# Out:
# RandomForestClassifier(random_state=666)

# %% [markdown]
# **Evaluate the model**

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy:.4f}")
# Out:
# Accuracy on test set: 0.6509

# %%
print("Classification report:\n", classification_report(y_test, y_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71      8964
#            1       0.63      0.49      0.55      7046
#
#     accuracy                           0.65     16010
#    macro avg       0.65      0.63      0.63     16010
# weighted avg       0.65      0.65      0.64     16010

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[6953 2011]
#  [3578 3468]]

# %% [markdown]
# **Feature Importance Visualization**

# %%
plt.figure(figsize=(12, 8))
importances = best_rfc.feature_importances_
indices = np.argsort(importances)[::-1]
sns.barplot(x=importances[indices], y=X_train.columns[indices])
plt.title('Feature Importances')
plt.show()

# %% [markdown]
# **Predict the classification for the test data**

# %%
test_data = pd.read_csv("test.csv")
X_true_test = test_data.drop(['query_id', 'url_id', 'id'], axis=1, errors='ignore')
X_true_test_scaled = scaler.transform(X_true_test)
predictions = best_rfc.predict(X_true_test_scaled)
results = pd.DataFrame({
    'prediction': predictions,
    'id': test_data['id']
})

results.to_csv("RandomForest_hyper.tuned_predictions.csv", index=False)

# %% [markdown]
# ## III. Boosting

# %% [markdown]
# **Split the data into training and test sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=666)

# %% [markdown]
# **Define the parameter grid for Grid Search**

# %%
param_grid = {
    'n_estimators': [50, 100, 150, 200],       # Number of boosting stages to be run
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Step size for updating weights
    'max_depth': [3, 5, 7, 10],                # Maximum depth of the individual trees
    'min_samples_split': [2, 5, 10],           # Minimum number of samples required to split an internal node
    'subsample': [0.8, 0.9, 1.0],             # Fraction of samples used for fitting individual trees
    'max_features': [None, 'sqrt', 'log2']    # Number of features to consider for the best split
}

# %% [markdown]
# **Initialize GridSearchCV with GradientBoostingClassifier**

# %%
grid_search = GridSearchCV(estimator=GBC(random_state=666),
                           param_grid=param_grid,
                           cv=5,                           # Number of cross-validation folds
                           scoring='accuracy',             # Scoring metric
                           n_jobs=-1)                       # Use all available CPUs

# %% [markdown]
# **Fit GridSearchCV to the training data**

# %%
grid_search.fit(X_train, y_train)

# %% [markdown]
# **Print the best parameters and the best score**

# %%
print(f"Best parameters: {grid_search.best_params_}")

# %%
print(f"Best score: {grid_search.best_score_:.4f}")

# %% [markdown]
# **Train the GradientBoostingClassifier with the best parameters**

# %%
best_gbc = grid_search.best_estimator_
y_pred = best_gbc.predict(X_test)
# Out:
# GradientBoostingClassifier(random_state=666)

# %% [markdown]
# **Evaluate the model**

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy:.4f}")
# Out:
# Accuracy on test set: 0.6583

# %%
print("Classification report:\n", classification_report(y_test, y_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.80      0.72      8964
#            1       0.65      0.48      0.55      7046
#
#     accuracy                           0.66     16010
#    macro avg       0.66      0.64      0.64     16010
# weighted avg       0.66      0.66      0.65     16010

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[7146 1818]
#  [3653 3393]]

# %% [markdown]
# **Feature Importance Visualization**

# %%
plt.figure(figsize=(12, 8))
importances = best_gbc.feature_importances_
indices = np.argsort(importances)[::-1]
sns.barplot(x=importances[indices], y=X_train.columns[indices])
plt.title('Feature Importances')
plt.show()

# %% [markdown]
# **Predict the classification for the test data**

# %%
test_data = pd.read_csv("test.csv")
X_true_test = test_data.drop(['query_id', 'url_id', 'id'], axis=1, errors='ignore')
X_true_test_scaled = scaler.transform(X_true_test)
predictions = best_gbc.predict(X_true_test_scaled)
results = pd.DataFrame({
    'prediction': predictions,
    'id': test_data['id']
})

results.to_csv("Boosting_hyper.tuned_predictions.csv", index=False)
